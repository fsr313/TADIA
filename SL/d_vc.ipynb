# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # que es la dimension VC
# ---
# es una medida que se utiliza en los algoritmos de clasificacion estadistica, donde se define la cardinalidad del mayor conjunto de puntos que un algoritmo puede separar.
#
# ---
# # aprendizaje estadistico
# ---
# La teoría del aprendizaje estadístico trata el problema de encontrar una función predictiva basada en datos. Los objetivos del aprendizaje son la comprensión y la predicción. El aprendizaje se divide en muchas categorías, incluido el aprendizaje supervisado, el aprendizaje no supervisado, el aprendizaje en línea y el aprendizaje por refuerzo.

# %%
x = np.linspace(1,20,300)
f_dvc = [(x**i)*np.exp(-x) for i in [2,3,5,10,15,20]]
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(1,1,1)

ax.set_yscale('log')

for a,b in zip (f_dvc, [2,3,5,10,15,20]):
    plt.plot(x,a, label = "{} dimension vc".format(b))
plt.legend()
